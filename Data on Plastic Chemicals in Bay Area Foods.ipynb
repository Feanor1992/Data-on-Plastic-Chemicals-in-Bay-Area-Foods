# %% [markdown]
# # Data on Plastic Chemicals in Bay Area Foods #

# %% [markdown]
# This Dash application analyzes data on plastic chemical levels in Bay Area foods. It provides interactive visualizations through tabs to explore the dataset, focusing on chemical concentrations, tag frequencies, and product collection locations.
#
# Key Functionalities:
# 1. **Data Cleaning and Preprocessing:**
#     - Converts chemical concentration values (e.g., DEHP, DBP) from strings with `<` or `>` symbols to numeric values for analysis.
#     - Removes outliers to ensure reliable visualizations.
#     - Drops columns with more than 20% missing data for better usability.
#     - Extracts latitude and longitude coordinates for visualization on a map using geocoding.
# 2. **Dash Application Layout:**
#     - ***Scatter Matrix:*** Displays relationships between different chemical concentrations.
#     - ***Tags Analysis:*** Shows the frequency of the most common tags associated with products.
#     - ***Locations Map:*** Maps the collection locations of the products.
#     - ***Individual Feature Analysis:*** Allows exploration of specific chemical concentration distributions via a dropdown menu.
# 3. Interactive Callbacks:
#     - Updates visualizations dynamically based on user interaction with the tabs or dropdown menus.

# %% [markdown]
# ### 1. Import libraries and Load the dataset ###

# %%
pip install geopy
# Out:
# Requirement already satisfied: geopy in c:\users\olcha\anaconda3\lib\site-packages (2.4.1)
# Requirement already satisfied: geographiclib<3,>=1.52 in c:\users\olcha\anaconda3\lib\site-packages (from geopy) (2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import dash
from dash import dcc, html, Input, Output
from dash import dash_table
import plotly.express as px
import plotly.graph_objects as go
import pandas as pd
from geopy.geocoders import Nominatim

# %% [markdown]
# ### 2. Load and clean dataset ###

# %%
df = pd.read_csv("samples.tsv", sep='\t')
df
# Out:
#            id  product_id                                            product  \
# 0     7090411          79               Ito En Oi Ocha Unsweetened Green Tea
# 1     7091001         136                   Whole Foods Non-Organic Broccoli
# 2     7091002           8                       Whole Foods Organic Broccoli
# 3     7091201          26      Clover Organic Whole Milk in Whole Gallon Jug
# 4     7091202          27    Clover Organic Whole Milk in Half Gallon Carton
# ..        ...         ...                                                ...
# 613  20240602          50  Colgate 360 Extra Soft Toothbrush for Sensitiv...
# 614  20240701          47  Whole Foods Organic Creamy Peanut Butter Unswe...
# 615  20240702          48                   PB2 Foods Peanut Butter Powdered
# 616  20240801          46                Whole Foods Organic Pasta Spaghetti
# 617  20240901           1        Enfamil Neuro Pro 587g Infant Formula (Tub)
#
#                                                   tags  \
# 0                                        tea,beverages
# 1                 produce,groceries,organic,vegetables
# 2                 produce,groceries,organic,vegetables
# 3    dairy,cow_milk,cow_milk_from_store,milk,organi...
# 4    dairy,carton,cow_milk,cow_milk_from_store,milk...
# ..                                                 ...
# 613                               personal_care,dental
# 614                       peanut_butter,modern,organic
# 615                                      peanut_butter
# 616                        dry_goods,groceries,organic
# 617                             baby_food,baby,formula
#
#      triplicate_1_sample_id  triplicate_2_sample_id              lot_no  \
# 0                       NaN                     NaN                4:49
# 1                       NaN                     NaN                 NaN
# 2                       NaN                     NaN                 NaN
# 3                       NaN                     NaN  08:15 PT9 SL 06499
# 4                       NaN                     NaN           72 06-499
# ..                      ...                     ...                 ...
# 613                     NaN                     NaN           4018CH30V
# 614                     NaN                     NaN       TB3355A 17:19
# 615                     NaN                     NaN     2:46 1124141110
# 616                     NaN                     NaN     L23326 5:51 T4S
# 617                     NaN                     NaN              EE4CUU
#
#     manufacturing_date expiration_date collected_on  ...  \
# 0                  NaN      2024-12-13   2024-07-09  ...
# 1                  NaN             NaN   2024-07-09  ...
# 2                  NaN             NaN   2024-07-09  ...
# 3                  NaN      2024-07-23   2024-07-09  ...
# 4                  NaN      2024-08-27   2024-07-09  ...
# ..                 ...             ...          ...  ...
# 613                NaN             NaN   2024-07-03  ...
# 614                NaN      2024-12-20   2024-07-03  ...
# 615                NaN      2025-09-20   2024-07-03  ...
# 616                NaN      2026-11-22   2024-07-03  ...
# 617                NaN      2025-10-01   2024-07-03  ...
#
#     DNHP_percent_tdi_70_kg_efsa DCHP_percent_tdi_70_kg_efsa  \
# 0                        NO TDI                      NO TDI
# 1                        NO TDI                      NO TDI
# 2                        NO TDI                      NO TDI
# 3                        NO TDI                      NO TDI
# 4                        NO TDI                      NO TDI
# ..                          ...                         ...
# 613                      NO TDI                      NO TDI
# 614                      NO TDI                      NO TDI
# 615                      NO TDI                      NO TDI
# 616                      NO TDI                      NO TDI
# 617                      NO TDI                      NO TDI
#
#     DNOP_percent_tdi_70_kg_efsa BPA_percent_tdi_70_kg_efsa  \
# 0                        NO TDI                       <LOQ
# 1                        NO TDI                       <LOQ
# 2                        NO TDI                       <LOQ
# 3                        NO TDI                       <LOQ
# 4                        NO TDI                       <LOQ
# ..                          ...                        ...
# 613                      NO TDI                       <LOQ
# 614                      NO TDI                       <LOQ
# 615                      NO TDI                       <LOQ
# 616                      NO TDI                       <LOQ
# 617                      NO TDI                       <LOQ
#
#     BPS_percent_tdi_70_kg_efsa BPF_percent_tdi_70_kg_efsa  \
# 0                       NO TDI                     NO TDI
# 1                       NO TDI                     NO TDI
# 2                       NO TDI                     NO TDI
# 3                       NO TDI                     NO TDI
# 4                       NO TDI                     NO TDI
# ..                         ...                        ...
# 613                     NO TDI                     NO TDI
# 614                     NO TDI                     NO TDI
# 615                     NO TDI                     NO TDI
# 616                     NO TDI                     NO TDI
# 617                     NO TDI                     NO TDI
#
#     DEHT_percent_tdi_70_kg_efsa DEHA_percent_tdi_70_kg_efsa  \
# 0                          <LOQ                        <LOQ
# 1                         0.006                        <LOQ
# 2                         0.008                        <LOQ
# 3                          0.03                        <LOQ
# 4                          0.02                        <LOQ
# ..                          ...                         ...
# 613                        <LOQ                        <LOQ
# 614                       0.002                        <LOQ
# 615                       0.001                        <LOQ
# 616                       0.004                        <LOQ
# 617                       0.003                        <LOQ
#
#     DINCH_percent_tdi_70_kg_efsa DIDA_percent_tdi_70_kg_efsa
# 0                           <LOQ                      NO TDI
# 1                           <LOQ                      NO TDI
# 2                           <LOQ                      NO TDI
# 3                           <LOQ                      NO TDI
# 4                           <LOQ                      NO TDI
# ..                           ...                         ...
# 613                         <LOQ                      NO TDI
# 614                         <LOQ                      NO TDI
# 615                         <LOQ                      NO TDI
# 616                         <LOQ                      NO TDI
# 617                         <LOQ                      NO TDI
#
# [618 rows x 173 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 618 entries, 0 to 617
# Columns: 173 entries, id to DIDA_percent_tdi_70_kg_efsa
# dtypes: float64(2), int64(3), object(168)
# memory usage: 835.4+ KB

# %%
# Clean the data
numeric_columns = [
    'DEHP_ng_serving',
    'DBP_ng_serving',
    'DEP_ng_serving',
    'BBP_ng_serving'
]
for col in numeric_columns:
    df[col] = df[col].str.replace('[<>]', '', regex=True).astype(float)

# Remove outliers
df_cleaned = df[
    (df['DBP_ng_serving'] < 8000) & 
    (df['DEHP_ng_serving'] < 20000)
]

df_cleaned.head()
# Out:
#         id  product_id                                          product  \
# 0  7090411          79             Ito En Oi Ocha Unsweetened Green Tea
# 1  7091001         136                 Whole Foods Non-Organic Broccoli
# 2  7091002           8                     Whole Foods Organic Broccoli
# 3  7091201          26    Clover Organic Whole Milk in Whole Gallon Jug
# 4  7091202          27  Clover Organic Whole Milk in Half Gallon Carton
#
#                                                 tags  triplicate_1_sample_id  \
# 0                                      tea,beverages                     NaN
# 1               produce,groceries,organic,vegetables                     NaN
# 2               produce,groceries,organic,vegetables                     NaN
# 3  dairy,cow_milk,cow_milk_from_store,milk,organi...                     NaN
# 4  dairy,carton,cow_milk,cow_milk_from_store,milk...                     NaN
#
#    triplicate_2_sample_id              lot_no manufacturing_date  \
# 0                     NaN                4:49                NaN
# 1                     NaN                 NaN                NaN
# 2                     NaN                 NaN                NaN
# 3                     NaN  08:15 PT9 SL 06499                NaN
# 4                     NaN           72 06-499                NaN
#
#   expiration_date collected_on  ... DNHP_percent_tdi_70_kg_efsa  \
# 0      2024-12-13   2024-07-09  ...                      NO TDI
# 1             NaN   2024-07-09  ...                      NO TDI
# 2             NaN   2024-07-09  ...                      NO TDI
# 3      2024-07-23   2024-07-09  ...                      NO TDI
# 4      2024-08-27   2024-07-09  ...                      NO TDI
#
#   DCHP_percent_tdi_70_kg_efsa DNOP_percent_tdi_70_kg_efsa  \
# 0                      NO TDI                      NO TDI
# 1                      NO TDI                      NO TDI
# 2                      NO TDI                      NO TDI
# 3                      NO TDI                      NO TDI
# 4                      NO TDI                      NO TDI
#
#   BPA_percent_tdi_70_kg_efsa BPS_percent_tdi_70_kg_efsa  \
# 0                       <LOQ                     NO TDI
# 1                       <LOQ                     NO TDI
# 2                       <LOQ                     NO TDI
# 3                       <LOQ                     NO TDI
# 4                       <LOQ                     NO TDI
#
#   BPF_percent_tdi_70_kg_efsa DEHT_percent_tdi_70_kg_efsa  \
# 0                     NO TDI                        <LOQ
# 1                     NO TDI                       0.006
# 2                     NO TDI                       0.008
# 3                     NO TDI                        0.03
# 4                     NO TDI                        0.02
#
#   DEHA_percent_tdi_70_kg_efsa DINCH_percent_tdi_70_kg_efsa  \
# 0                        <LOQ                         <LOQ
# 1                        <LOQ                         <LOQ
# 2                        <LOQ                         <LOQ
# 3                        <LOQ                         <LOQ
# 4                        <LOQ                         <LOQ
#
#   DIDA_percent_tdi_70_kg_efsa
# 0                      NO TDI
# 1                      NO TDI
# 2                      NO TDI
# 3                      NO TDI
# 4                      NO TDI
#
# [5 rows x 173 columns]

# %%
# Drop columns with more than 40% missing values
df_cleaned = df_cleaned.loc[:, df_cleaned.isnull().mean() <= 0.2]
df_cleaned.head()
# Out:
#         id  product_id                                          product  \
# 0  7090411          79             Ito En Oi Ocha Unsweetened Green Tea
# 1  7091001         136                 Whole Foods Non-Organic Broccoli
# 2  7091002           8                     Whole Foods Organic Broccoli
# 3  7091201          26    Clover Organic Whole Milk in Whole Gallon Jug
# 4  7091202          27  Clover Organic Whole Milk in Half Gallon Carton
#
#                                                 tags collected_on  \
# 0                                      tea,beverages   2024-07-09
# 1               produce,groceries,organic,vegetables   2024-07-09
# 2               produce,groceries,organic,vegetables   2024-07-09
# 3  dairy,cow_milk,cow_milk_from_store,milk,organi...   2024-07-09
# 4  dairy,carton,cow_milk,cow_milk_from_store,milk...   2024-07-09
#
#                                         collected_at           blinded_name  \
# 0  Whole Foods Market, 1250 Jefferson Ave, Redwoo...  Unsweetened green tea
# 1  Whole Foods Market, 1250 Jefferson Ave, Redwoo...               Broccoli
# 2  Whole Foods Market, 1250 Jefferson Ave, Redwoo...               Broccoli
# 3  Safeway, 1071 El Camino Real, Redwood City, CA...       Pasteurized milk
# 4  Safeway, 1071 El Camino Real, Redwood City, CA...       Pasteurized milk
#
#    blinded_photo  shipped_on          shipped_in  ...  \
# 0  07090411 .jpg  2024-07-10  Original packaging  ...
# 1   07091001.jpg  2024-07-10          Ziploc bag  ...
# 2   07091002.jpg  2024-07-10          Ziploc bag  ...
# 3   07091201.jpg  2024-07-10  Original packaging  ...
# 4   07091202.jpg  2024-07-10  Original packaging  ...
#
#   DNHP_percent_tdi_70_kg_efsa DCHP_percent_tdi_70_kg_efsa  \
# 0                      NO TDI                      NO TDI
# 1                      NO TDI                      NO TDI
# 2                      NO TDI                      NO TDI
# 3                      NO TDI                      NO TDI
# 4                      NO TDI                      NO TDI
#
#   DNOP_percent_tdi_70_kg_efsa BPA_percent_tdi_70_kg_efsa  \
# 0                      NO TDI                       <LOQ
# 1                      NO TDI                       <LOQ
# 2                      NO TDI                       <LOQ
# 3                      NO TDI                       <LOQ
# 4                      NO TDI                       <LOQ
#
#   BPS_percent_tdi_70_kg_efsa BPF_percent_tdi_70_kg_efsa  \
# 0                     NO TDI                     NO TDI
# 1                     NO TDI                     NO TDI
# 2                     NO TDI                     NO TDI
# 3                     NO TDI                     NO TDI
# 4                     NO TDI                     NO TDI
#
#   DEHT_percent_tdi_70_kg_efsa DEHA_percent_tdi_70_kg_efsa  \
# 0                        <LOQ                        <LOQ
# 1                       0.006                        <LOQ
# 2                       0.008                        <LOQ
# 3                        0.03                        <LOQ
# 4                        0.02                        <LOQ
#
#   DINCH_percent_tdi_70_kg_efsa DIDA_percent_tdi_70_kg_efsa
# 0                         <LOQ                      NO TDI
# 1                         <LOQ                      NO TDI
# 2                         <LOQ                      NO TDI
# 3                         <LOQ                      NO TDI
# 4                         <LOQ                      NO TDI
#
# [5 rows x 167 columns]

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 596 entries, 0 to 617
# Columns: 167 entries, id to DIDA_percent_tdi_70_kg_efsa
# dtypes: float64(4), int64(3), object(160)
# memory usage: 782.2+ KB

# %%
# Extract data for tags analysis
tag_counts = df_cleaned['tags'].dropna().str.split(',').explode().value_counts().head(10)
tag_counts
# Out:
# tags
# groceries         173
# beverages         132
# fast_food          83
# water              80
# organic            61
# prepared_meals     53
# baby               46
# tap_water          40
# palo_alto          38
# health             37
# Name: count, dtype: int64

# %%
# Extract data for collected_at map visualization
geolocator = Nominatim(user_agent='map_app')

def geocode_address(address):
    try:
        location = geolocator.geocode(address)
        if location:
            return location.latitude, location.longitude
        else:
            return None, None
    except Exception as e:
        print(f'Error in geocode {address}: {e}')
        return None, None

df_cleaned[['latitude', 'longitude']] = df_cleaned['collected_at'].apply(
    lambda x: pd.Series(geocode_address(x))
)

df_with_coordinates = df_cleaned.dropna(subset=['latitude', 'longitude']).reset_index(drop=True)

df_with_coordinates.head()
# Out:
# Error in geocode Safeway, 1071 El Camino Real, Redwood City, CA 94063: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Safeway%2C+1071+El+Camino+Real%2C+Redwood+City%2C+CA+94063&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# Error in geocode CVS: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=CVS&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# Error in geocode Blue Bottle Coffee, 315 Linden St, San Francisco, CA 94102: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Blue+Bottle+Coffee%2C+315+Linden+St%2C+San+Francisco%2C+CA+94102&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# Error in geocode CVS Pharmacy, 855 El Camino Real, Palo Alto, CA 94301: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=CVS+Pharmacy%2C+855+El+Camino+Real%2C+Palo+Alto%2C+CA+94301&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# Error in geocode Blue Bottle Coffee, 315 Linden St, San Francisco, CA 94102: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Blue+Bottle+Coffee%2C+315+Linden+St%2C+San+Francisco%2C+CA+94102&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# Error in geocode Milk bank in the Bay Area: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Milk+bank+in+the+Bay+Area&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# Error in geocode Whole Foods Market, 4800 El Camino Real, Los Altos, CA 94022: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Whole+Foods+Market%2C+4800+El+Camino+Real%2C+Los+Altos%2C+CA+94022&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# Error in geocode CVS: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=CVS&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# Error in geocode Domino's Pizza, 615 Caliente Dr, Sunnyvale, CA 94085: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Domino%27s+Pizza%2C+615+Caliente+Dr%2C+Sunnyvale%2C+CA+94085&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# Error in geocode Taco Bell, 485 N Mathilda Ave, Sunnyvale, CA 94085: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Taco+Bell%2C+485+N+Mathilda+Ave%2C+Sunnyvale%2C+CA+94085&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# Error in geocode CVS: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=CVS&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# Error in geocode Whole Foods Market, 4800 El Camino Real, Los Altos, CA 94022: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Whole+Foods+Market%2C+4800+El+Camino+Real%2C+Los+Altos%2C+CA+94022&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# Error in geocode Whole Foods Market, 4800 El Camino Real, Los Altos, CA 94022: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Whole+Foods+Market%2C+4800+El+Camino+Real%2C+Los+Altos%2C+CA+94022&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# Error in geocode CVS: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=CVS&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# Error in geocode Farmers' Market, 1799 Locust St, Walnut Creek, CA 94596: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Farmers%27+Market%2C+1799+Locust+St%2C+Walnut+Creek%2C+CA+94596&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# Error in geocode Whole Foods Market, 4800 El Camino Real, Los Altos, CA 94022: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Whole+Foods+Market%2C+4800+El+Camino+Real%2C+Los+Altos%2C+CA+94022&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# Error in geocode 7-Eleven, 401 Waverley St, Palo Alto, CA 94301: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=7-Eleven%2C+401+Waverley+St%2C+Palo+Alto%2C+CA+94301&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# Error in geocode Milk bank in the Bay Area: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Milk+bank+in+the+Bay+Area&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# Error in geocode 7-Eleven, 401 Waverley St, Palo Alto, CA 94301: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=7-Eleven%2C+401+Waverley+St%2C+Palo+Alto%2C+CA+94301&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#         id  product_id                                       product  \
# 0  7090411          79          Ito En Oi Ocha Unsweetened Green Tea
# 1  7091001         136              Whole Foods Non-Organic Broccoli
# 2  7091002           8                  Whole Foods Organic Broccoli
# 3  7091602          82               Good Farms Organic Strawberries
# 4  7091702         117  Straus Organic Whole Milk Plain Greek Yogurt
#
#                                    tags collected_on  \
# 0                         tea,beverages   2024-07-09
# 1  produce,groceries,organic,vegetables   2024-07-09
# 2  produce,groceries,organic,vegetables   2024-07-09
# 3      produce,fruits,groceries,organic   2024-07-09
# 4       yogurt,dairy,organic,whole_milk   2024-07-09
#
#                                         collected_at             blinded_name  \
# 0  Whole Foods Market, 1250 Jefferson Ave, Redwoo...    Unsweetened green tea
# 1  Whole Foods Market, 1250 Jefferson Ave, Redwoo...                 Broccoli
# 2  Whole Foods Market, 1250 Jefferson Ave, Redwoo...                 Broccoli
# 3  Whole Foods Market, 1250 Jefferson Ave, Redwoo...               Strawberry
# 4  Whole Foods Market, 1250 Jefferson Ave, Redwoo...  Whole milk Greek yogurt
#
#    blinded_photo  shipped_on          shipped_in  ...  \
# 0  07090411 .jpg  2024-07-10  Original packaging  ...
# 1   07091001.jpg  2024-07-10          Ziploc bag  ...
# 2   07091002.jpg  2024-07-10          Ziploc bag  ...
# 3   07091602.jpg  2024-07-10          Ziploc bag  ...
# 4   07091702.jpg  2024-07-10  Original packaging  ...
#
#   DNOP_percent_tdi_70_kg_efsa BPA_percent_tdi_70_kg_efsa  \
# 0                      NO TDI                       <LOQ
# 1                      NO TDI                       <LOQ
# 2                      NO TDI                       <LOQ
# 3                      NO TDI                       <LOQ
# 4                      NO TDI                       <LOQ
#
#   BPS_percent_tdi_70_kg_efsa BPF_percent_tdi_70_kg_efsa  \
# 0                     NO TDI                     NO TDI
# 1                     NO TDI                     NO TDI
# 2                     NO TDI                     NO TDI
# 3                     NO TDI                     NO TDI
# 4                     NO TDI                     NO TDI
#
#   DEHT_percent_tdi_70_kg_efsa DEHA_percent_tdi_70_kg_efsa  \
# 0                        <LOQ                        <LOQ
# 1                       0.006                        <LOQ
# 2                       0.008                        <LOQ
# 3                        0.01                        <LOQ
# 4                       0.008                        <LOQ
#
#   DINCH_percent_tdi_70_kg_efsa DIDA_percent_tdi_70_kg_efsa   latitude  \
# 0                         <LOQ                      NO TDI  37.482281
# 1                         <LOQ                      NO TDI  37.482281
# 2                         <LOQ                      NO TDI  37.482281
# 3                         <LOQ                      NO TDI  37.482281
# 4                         <LOQ                      NO TDI  37.482281
#
#     longitude
# 0 -122.231695
# 1 -122.231695
# 2 -122.231695
# 3 -122.231695
# 4 -122.231695
#
# [5 rows x 169 columns]

# %% [markdown]
# ### 3. Dash app ###

# %%
app = dash.Dash(__name__)

# %%
app.layout = html.Div([
    html.H1('Data on Plastic Chemicals in Bay Area Foods'),
    dcc.Tabs([
        dcc.Tab(
            label='Scatter Matrix',
            children=[dcc.Graph(id='scatter-matrix')]
        ),
        dcc.Tab(
            label='Tags Analysis',
            children=[dcc.Graph(id='tags-bar-chart')]
        ),
        dcc.Tab(
            label='Locations Map',
            children=[dcc.Graph(id='locations-map')]
        ),
        dcc.Tab(
            label='Individual Feature Analysis',
            children=[
                dcc.Dropdown(
                    id='feature-dropdown',
                    options=[
                        {'label': 'DEHP_ng_serving', 'value': 'DEHP_ng_serving'},
                        {'label': 'DBP_ng_serving', 'value': 'DBP_ng_serving'},
                        {'label': 'DEP_ng_serving', 'value': 'DEP_ng_serving'},
                        {'label': 'BBP_ng_serving', 'value': 'BBP_ng_serving'}
                    ],
                    value='DEHP_ng_serving',
                    placeholder='Select a feature'
                ),
                dcc.Graph(id='feature-bar-chart')
            ]
        ),
    ])
])

# %%
@app.callback(
    Output('scatter-matrix', 'figure'),
    Input('scatter-matrix', 'id')
)
def update_scatter_matrix(_):
    fig = px.scatter_matrix(
        df_cleaned,
        dimensions=["DEHP_ng_serving", "DBP_ng_serving", "DEP_ng_serving", "BBP_ng_serving"],
        title="Scatter Matrix of Chemical Levels"
    )
    fig.update_xaxes(title_text='Chemical Levels (ng per serving)', tickangle=45)
    return fig

@app.callback(
    Output('tags-bar-chart', 'figure'),
    Input('tags-bar-chart', 'id')
)
def update_tags_bar_chart(_):
    fig = px.bar(
        x=tag_counts.index,
        y=tag_counts.values,
        title="Top 10 Tag Frequency",
        labels={"x": "Tag", "y": "Count"}
    )
    return fig

@app.callback(
    Output('locations-map', 'figure'),
    Input('locations-map', 'id')
)

def update_locations_map(_):
    # Пример проверки, что данные для карты корректны
    if 'latitude' not in df_cleaned.columns or 'longitude' not in df_cleaned.columns:
        raise ValueError("DataFrame must contain 'latitude' and 'longitude' columns.")
    
    fig = px.scatter_mapbox(
        df_cleaned,
        lat="latitude",
        lon="longitude",
        text="product",
        zoom=10,
        title="Map of Product Locations",
    )
    fig.update_layout(mapbox_style="open-street-map")
    return fig

@app.callback(
    Output('feature-bar-chart', 'figure'),
    Input('feature-dropdown', 'value')
)
def update_feature_bar_chart(selected_feature):
    if selected_feature:
        fig = px.histogram(
            df_cleaned,
            x=selected_feature,
            title=f"Distribution of {selected_feature}"
        )
        return fig
    return {}

# %%
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### Explanation of Visualizations: ###
# 1. **Scatter Matrix (Scatter Matrix of Chemical Levels):**
#     - ***Purpose:*** Examines correlations and relationships between different chemical concentrations in food products.
#     - ***Interpretation:*** Diagonal plots show the distributions of individual chemical levels, while off-diagonal scatter plots reveal how two chemicals vary relative to one another.
# 2. **Tags Analysis (Top 10 Tag Frequency):**
#     - ***Purpose:*** Highlights the most common tags (e.g., product types or categories) in the dataset.
#     - ***Interpretation:*** A bar chart where the x-axis shows the tags, and the y-axis indicates their frequency, providing insights into prevalent product categories.
# 3. **Locations Map (Map of Product Locations):**
#     - ***Purpose:*** Visualizes the geographic distribution of product collection locations.
#     - ***Interpretation:*** Each point represents a product, with its geographic location determined by the geocoded `collected_at` field. Useful for identifying spatial trends in sampling.
# 4. **Individual Feature Analysis (Distribution of Selected Chemical):**
#     - ***Purpose:*** Displays the distribution of a selected chemical (e.g., DEHP or DBP) to analyze concentration levels in products.
#     - ***Interpretation:*** A histogram showing the frequency of specific concentration ranges. Peaks indicate common values, and the spread reflects variability.
